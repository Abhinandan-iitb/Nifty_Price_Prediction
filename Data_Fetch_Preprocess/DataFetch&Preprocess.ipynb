# %%
from fyers_apiv3 import fyersModel

# %%
client_id = "P7R312V9VL-100"
secret_key = "965HTXV7LC"
redirect_uri = "https://www.google.com/"
response_type = "code"
grant_type = "authorization_code"
state = "none"

# %%
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key,
    redirect_uri=redirect_uri,
    response_type=response_type
)

# %%
response = session.generate_authcode()

# %%
print(response)
# Out:
# https://api-t1.fyers.in/api/v3/generate-authcode?client_id=P7R312V9VL-100&redirect_uri=https%3A%2F%2Fwww.google.com%2F&response_type=code&state=None

# %%
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type="authorization_code"
)
session.set_token("eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....v5XyN8ApBEDQiZSauElqyf2LZRJ47iR48swaup_8NMI")
access_token = session.generate_token()
print(access_token)
# Out:
# {'s': 'ok', 'code': 200, 'message': '', 'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....oFxl-Q4ZxluYLSqyIgJui5cbFTXKsCWw1NJVaJH8PqU', 'refresh_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....fqTBv3uRURZ9L6J04sN2_puU-ZYINo3XR8nY5kgk4-Q'}

# %%
access_token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....oFxl-Q4ZxluYLSqyIgJui5cbFTXKsCWw1NJVaJH8PqU"
print(access_token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....oFxl-Q4ZxluYLSqyIgJui5cbFTXKsCWw1NJVaJH8PqU

# %%
fyers = fyersModel.FyersModel(client_id=client_id, is_async=False,token=access_token, log_path="")
fyers

# %%
from datetime import datetime, timedelta
symbol = "NSE:INDIAVIX-INDEX"
start_date = datetime(2015, 1, 1)
end_date = datetime(2024, 11, 14)
all_data = []    
while start_date < end_date:
    next_end_date = min(start_date + timedelta(days=100), end_date)
    data = fyers.history({
        "symbol": symbol,
        "resolution": "30",
        "date_format": "1",
        "range_from": start_date.strftime('%Y-%m-%d'),
        "range_to": next_end_date.strftime('%Y-%m-%d'),
        "cont_flag": "1"
    })
    if 'candles' in data:
        all_data.extend(data['candles'])
    start_date = next_end_date + timedelta(days=1)

# %%
all_data
# Out:
# [[1500261300, 11.17, 11.17, 11.17, 11.17, 0],
#  [1500263100, 11.17, 11.45, 10.48, 11.41, 0],
#  [1500264900, 11.4, 11.56, 11.22, 11.45, 0],
#  [1500266700, 11.45, 11.53, 11.38, 11.46, 0],
#  [1500268500, 11.46, 11.49, 11.34, 11.42, 0],
#  [1500270300, 11.42, 11.52, 11.37, 11.49, 0],
#  [1500272100, 11.5, 11.57, 11.44, 11.55, 0],
#  [1500273900, 11.55, 11.55, 11.37, 11.39, 0],
#  [1500275700, 11.39, 11.48, 11.27, 11.34, 0],
#  [1500277500, 11.34, 11.4, 11.26, 11.37, 0],
#  [1500279300, 11.37, 11.41, 11.28, 11.35, 0],
#  [1500281100, 11.35, 11.44, 11.32, 11.38, 0],
#  [1500282900, 11.37, 11.48, 11.3, 11.46, 0],
#  [1500284700, 11.45, 11.52, 11.41, 11.47, 0],
#  [1500347700, 11.46, 11.46, 11.46, 11.46, 0],
#  [1500349500, 10.87, 11.79, 10.87, 11.68, 0],
#  [1500351300, 11.7, 11.7, 11.56, 11.57, 0],
#  [1500353100, 11.56, 11.61, 11.47, 11.51, 0],
#  [1500354900, 11.51, 11.61, 11.46, 11.46, 0],
#  [1500356700, 11.47, 11.52, 11.35, 11.37, 0],
# ...

# %%
import pandas as pd
df = pd.DataFrame(all_data, columns=["date", "open", "high", "low", "close", "volume"])
#df['date'] = pd.to_datetime(df['date'], unit='s')
df.to_csv('CodedVIX_Data_2015_to_2024.csv', index=False)

# %%
symbol = "NSE:NIFTY50-INDEX"
from datetime import datetime, timedelta
start_date = datetime(2015, 1, 1)
end_date = datetime(2024, 11, 14)
all_data = []    
while start_date < end_date:
    next_end_date = min(start_date + timedelta(days=100), end_date)
    data = fyers.history({
        "symbol": symbol,
        "resolution": "30",
        "date_format": "1",
        "range_from": start_date.strftime('%Y-%m-%d'),
        "range_to": next_end_date.strftime('%Y-%m-%d'),
        "cont_flag": "1"
    })
    if 'candles' in data:
        all_data.extend(data['candles'])
    start_date = next_end_date + timedelta(days=1)
all_data
# Out:
# [[1500261300, 9908.15, 9908.15, 9908.15, 9908.15, 0],
#  [1500263100, 9908.15, 9915.15, 9894.85, 9897.7, 0],
#  [1500264900, 9899.05, 9916.7, 9898.45, 9915.3, 0],
#  [1500266700, 9915.45, 9920.3, 9911.8, 9917.75, 0],
#  [1500268500, 9917.4, 9920.15, 9913.85, 9915.25, 0],
#  [1500270300, 9915.4, 9916.55, 9902.75, 9910.15, 0],
#  [1500272100, 9910.05, 9914.55, 9903.75, 9904.7, 0],
#  [1500273900, 9904.75, 9910.75, 9902.6, 9907.75, 0],
#  [1500275700, 9907.9, 9911.1, 9905.9, 9907.05, 0],
#  [1500277500, 9907.25, 9914.65, 9904.3, 9911.2, 0],
#  [1500279300, 9911.3, 9917.3, 9908.85, 9917.3, 0],
#  [1500281100, 9917.4, 9924.05, 9916, 9921, 0],
#  [1500282900, 9921.1, 9928.2, 9919.25, 9919.9, 0],
#  [1500284700, 9919.05, 9921.3, 9910.4, 9913.65, 0],
#  [1500347700, 9832.7, 9832.7, 9832.7, 9832.7, 0],
#  [1500349500, 9863.5, 9877.65, 9853.25, 9871.7, 0],
#  [1500351300, 9872.35, 9884.45, 9872.35, 9873.35, 0],
#  [1500353100, 9872.75, 9875.7, 9871.45, 9872.65, 0],
# ...

# %%
df = pd.DataFrame(all_data, columns=["date", "open", "high", "low", "close", "volume"])
#df['date'] = pd.to_datetime(df['date'], unit='s')
df.to_csv('CodedNIFTY_Data_2015_to_2024.csv', index=False)

# %%
dataNifty24 = fyers.history({
        "symbol": "NSE:INDIAVIX-INDEX",
        "resolution": "D",
        "date_format": "1",
        "range_from": "2024-01-01",
        "range_to": "2024-11-14",
        "cont_flag": "1"
    })
dataNifty24
# Out:
# {'candles': [[1704067200, 14.5, 14.87, 14.33, 14.68, 0],
#   [1704153600, 14.68, 15.08, 14.24, 14.58, 0],
#   [1704240000, 14.58, 14.78, 14.02, 14.1, 0],
#   [1704326400, 14.1, 14.21, 13.21, 13.33, 0],
#   [1704412800, 13.33, 13.47, 12.49, 12.63, 0],
#   [1704672000, 12.63, 13.6, 12.63, 13.46, 0],
#   [1704758400, 13.46, 13.51, 12.78, 13.26, 0],
#   [1704844800, 13.26, 14.56, 12.81, 12.97, 0],
#   [1704931200, 12.97, 13.19, 12.63, 12.77, 0],
#   [1705017600, 12.77, 13.29, 12.42, 13.1, 0],
#   [1705276800, 13.1, 13.89, 11.79, 13.79, 0],
#   [1705363200, 13.79, 14.04, 12.49, 13.57, 0],
#   [1705449600, 13.57, 15.23, 12.72, 15.08, 0],
#   [1705536000, 15.08, 15.71, 12.98, 14.07, 0],
#   [1705622400, 14.07, 14.11, 13.68, 13.88, 0],
#   [1705708800, 13.88, 14.25, 13.1, 13.8, 0],
#   [1705968000, 13.8, 15.41, 12.2, 14.85, 0],
#   [1706054400, 14.85, 15.65, 14.03, 14.38, 0],
#   [1706140800, 14.38, 15.34, 13.36, 13.87, 0],
#   [1706486400, 13.87, 15.85, 13.8, 15.68, 0],
# ...

# %%
df = pd.DataFrame(dataNifty15['candles'], columns=["date", "open", "high", "low", "close", "volume"])
df['date'] = pd.to_datetime(df['date'], unit='s')
df.to_csv('VIX_Data2015.csv', index=False)

# %%
start_date="2017-01-01"
end_date="2024-11-14"
start_date_obj = datetime.strptime(start_date, "%Y-%m-%d")
end_date_obj = datetime.strptime(end_date, "%Y-%m-%d")
expiry_dates = []
current_date = start_date_obj
while current_date <= end_date_obj:
        # Set the expiry date to the last Thursday of the current month
    last_day = (current_date.replace(day=1) + timedelta(days=31)).replace(day=1) - timedelta(days=1)
    expiry_date = last_day - timedelta(days=(last_day.weekday() - 3) % 7)
    expiry_dates.append(expiry_date)
    current_date = current_date + timedelta(days=31)
    current_date = current_date.replace(day=1)
expiry_dates
# Out:
# [datetime.datetime(2017, 1, 26, 0, 0),
#  datetime.datetime(2017, 2, 23, 0, 0),
#  datetime.datetime(2017, 3, 30, 0, 0),
#  datetime.datetime(2017, 4, 27, 0, 0),
#  datetime.datetime(2017, 5, 25, 0, 0),
#  datetime.datetime(2017, 6, 29, 0, 0),
#  datetime.datetime(2017, 7, 27, 0, 0),
#  datetime.datetime(2017, 8, 31, 0, 0),
#  datetime.datetime(2017, 9, 28, 0, 0),
#  datetime.datetime(2017, 10, 26, 0, 0),
#  datetime.datetime(2017, 11, 30, 0, 0),
#  datetime.datetime(2017, 12, 28, 0, 0),
#  datetime.datetime(2018, 1, 25, 0, 0),
#  datetime.datetime(2018, 2, 22, 0, 0),
#  datetime.datetime(2018, 3, 29, 0, 0),
#  datetime.datetime(2018, 4, 26, 0, 0),
#  datetime.datetime(2018, 5, 31, 0, 0),
#  datetime.datetime(2018, 6, 28, 0, 0),
#  datetime.datetime(2018, 7, 26, 0, 0),
#  datetime.datetime(2018, 8, 30, 0, 0),
#  datetime.datetime(2018, 9, 27, 0, 0),
#  datetime.datetime(2018, 10, 25, 0, 0),
#  datetime.datetime(2018, 11, 29, 0, 0),
#  datetime.datetime(2018, 12, 27, 0, 0),
# ...

# %%
all_data = []
for expiry_date in expiry_dates:
    expiry_str = expiry_date.strftime("%y%b").upper()  # Format to match symbol pattern (e.g., "23NOV")
    symbol = f"NSE:NIFTY{expiry_str}FUT"
    data = fetch_nifty_futures_data(
        symbol=symbol,
        from_date=start_date,
        to_date=min(expiry_date.strftime("%Y-%m-%d"), end_date)
    )
    if data:
            # Convert to DataFrame and store
        df = pd.DataFrame(data, columns=["timestamp", "open", "high", "low", "close", "volume"])
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
        df['symbol'] = symbol
        all_data.append(df)
